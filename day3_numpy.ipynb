# %%
# !pip install numpy

# %%
plt.bar(range(1, 11), df["Scores"][:10], color="green")
plt.title("Scores of First 10 Students")
plt.xlabel("Student Number")
plt.ylabel("Score")
plt.show()

# %%
plt.plot(df["Scores"][:15], marker="o", color="orange")
plt.title("Score Trend (First 15 Students)")
plt.xlabel("Student Index")
plt.ylabel("Score")
plt.show()

# %%
import numpy as np

# %%
study_hours = np.array([2, 3, 4, 1, 5, 6, 2])
print(study_hours)
print(type(study_hours))

# %%
print(study_hours[0])   # first value -> 2
print(study_hours[3])   # fourth value -> 1
print(study_hours[-1])  # last value -> 2

# %%
print(study_hours[0:3])   # first 3 values -> [2 3 4]
print(study_hours[3:])    # from index 3 to the end -> [1 5 6 2]
print(study_hours + 1)      # adds 1 to every value
print(study_hours * 2)      # doubles every value
print(study_hours.sum())    # adds up all values -> total hours
print(study_hours.mean())   # average hours per day
print(study_hours.max())    # highest value
print(study_hours.min())    # lowest value

# %%
data = np.array([[2, 65], [3, 70], [4, 75], [5, 85]])
print(data)
print(data.shape)   # (4, 2) -> 4 rows, 2 columns
