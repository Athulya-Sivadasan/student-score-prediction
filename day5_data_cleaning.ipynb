# %%
import pandas as pd

df = pd.read_csv("student_scores_raw.csv")
df
# Out:
#     Hours  Scores
# 0     8.1    78.6
# 1     5.5    55.2
# 2     9.4    91.5
# 3     2.6    17.2
# 4     1.3     5.9
# 5     1.5    16.3
# 6     2.5    25.2
# 7     7.1    70.3
# 8     1.3     5.1
# 9     6.8    57.3
# 10    2.9    34.5
# 11    3.0    24.1
# 12    3.8    31.5
# 13    4.1    34.5
# 14    1.2     7.1
# 15    9.5    90.7
# 16    7.8    66.2
# 17    2.9    23.5
# 18    8.5    74.1
# 19    1.4     9.7
# 20    7.8     NaN
# 21    5.6    49.4
# 22    1.1     8.6
# 23    8.7    82.0
# 24    6.4    59.1
# 25    2.0    22.7
# 26    8.5    74.1
# 27    2.5    23.8
# 28    6.2    56.7
# 29    2.4    29.9
# 30    NaN    33.3
# 31    9.1    83.8
# 32    8.3    80.1
# 33    0.7     1.8
# 34    8.4    76.8
# 35    3.6    28.7
# 36    8.1    81.4
# 37    5.3    57.9
# 38    6.8    57.3
# 39    2.0    17.1
# 40    7.8    77.3
# 41    6.3     NaN
# 42    8.0    77.9
# 43    9.2    93.2
# 44    2.6    21.3
# 45    5.8    61.5
# 46    3.9    37.9
# 47    3.3    27.6
# 48    7.8    77.3
# 49    6.3    60.6
# 50    7.6    71.0
# 51    9.5    90.4
# 52    6.3    52.3

# %%
df.isnull().sum()
# Out:
# Hours     1
# Scores    2
# dtype: int64

# %%
df.describe()
# Out:
#            Hours     Scores
# count  52.000000  51.000000
# mean    5.367308  48.849020
# std     2.820146  27.975635
# min     0.700000   1.800000
# 25%     2.600000  23.950000
# 50%     6.000000  55.200000
# 75%     7.850000  75.450000
# max     9.500000  93.200000

# %%
df.duplicated().sum()
# Out:
# np.int64(3)

# %%
df[df.duplicated()]
# Out:
#     Hours  Scores
# 26    8.5    74.1
# 38    6.8    57.3
# 48    7.8    77.3

# %%
df["Hours"] = df["Hours"].fillna(df["Hours"].mean())
df["Scores"] = df["Scores"].fillna(df["Scores"].mean())

# %%
df = df.drop_duplicates()

# %%
print("Missing values:\n", df.isnull().sum())
print("\nDuplicate rows:", df.duplicated().sum())
print("\nShape after cleaning:", df.shape)
# Out:
# Missing values:
#  Hours     0
# Scores    0
# dtype: int64
#
# Duplicate rows: 0
#
# Shape after cleaning: (50, 2)

# %%
df.to_csv("student_scores_clean.csv", index=False)
